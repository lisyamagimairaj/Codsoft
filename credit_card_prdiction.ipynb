# %% [markdown]
# <a href="https://colab.research.google.com/github/lisyamagimairaj/Codsoft/blob/main/credit_card_prdiction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('credit.csv')
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 20409  31025 -0.724757  0.649594  1.727010 -0.539584  0.889184 -1.034725
# 20410  31026 -2.317953 -0.691477  1.265161 -0.376933  2.573624 -1.276860
# 20411  31026 -1.327280  1.224650  0.796178  1.153083 -0.236519  0.924243
# 20412  31027  0.132756 -0.431359 -0.909160 -3.105432  1.878086  2.976224
# 20413  31027  1.257126  0.344870  0.303501  0.694626 -0.385154 -1.077230
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %% [markdown]
# **pre processing**

# %% [markdown]
# **checking null value,displaying**

# %%
print(df.isnull().sum())
print(df.describe())
print(df['Class'].value_counts())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64
#                Time            V1            V2            V3            V4  \
# count  20414.000000  20414.000000  20414.000000  20414.000000  20414.000000
# mean   15880.030126     -0.244137      0.235304      0.746259      0.273772
# std    10653.852085      1.886242      1.523911      1.757284      1.461833
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%     4766.750000     -0.960555     -0.334134      0.307746     -0.638723
# 50%    15833.000000     -0.302521      0.214177      0.896730      0.225655
# ...

# %% [markdown]
# Feature scaling

# %%
scaler = StandardScaler()
df['Amount'] = scaler.fit_transform(df[['Amount']])

# %% [markdown]
# pre-processing

# %%
df = df.dropna(subset=['Class'])
X = df.drop(['Class', 'Time'], axis=1)
y = df['Class']
print("Checking for null values in features:")
print(X.isnull().sum())
X = X.dropna()
y = y.loc[X.index]
scaler = StandardScaler()
X['Amount'] = scaler.fit_transform(X[['Amount']])
# Out:
# Checking for null values in features:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# dtype: int64

# %% [markdown]
# **splitting**

# %%
X = df.drop(['Class', 'Time'], axis=1)
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# training model using random forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# evaluating

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred = model.predict(X_test)
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[6096    2]
#  [   3   23]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      6098
#          1.0       0.92      0.88      0.90        26
#
#     accuracy                           1.00      6124
#    macro avg       0.96      0.94      0.95      6124
# weighted avg       1.00      1.00      1.00      6124
#
#
# Accuracy Score:
# 0.9991835401698237

# %%
#overall coding
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Loading the dataset
data = pd.read_csv('credit.csv')

# Checking for null values
print("Checking for null values:")
print(data.isnull().sum())

# Droping rows where y is NaN
data = data.dropna(subset=['Class'])

# Separate features and target
X = data.drop(['Class', 'Time'], axis=1)
y = data['Class']

# Check for null values in features and drop them
X = X.dropna()
y = y.loc[X.index]  # Ensure y matches the indices of the cleaned X

# Feature scaling for 'Amount'
scaler = StandardScaler()
X['Amount'] = scaler.fit_transform(X[['Amount']])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Initialize the model
model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred))
# Out:
# Checking for null values:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64
# Confusion Matrix:
# [[7842    2]
#  [   4   22]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      7844
#          1.0       0.92      0.85      0.88        26
#
#     accuracy                           1.00      7870
#    macro avg       0.96      0.92      0.94      7870
# weighted avg       1.00      1.00      1.00      7870
#
#
# Accuracy Score:
# 0.9992376111817026
